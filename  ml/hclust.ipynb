# %% [markdown]
# <a href="https://colab.research.google.com/github/applejxd/colaboratory/blob/master/%20ml/hclust.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install --upgrade pycaret pandas-profiling==3.1.0

# %%
from sklearn.datasets import fetch_openml

data, target = fetch_openml("mnist_784", version=1, return_X_y=True)
print(f"x_data.shape={data.shape}")
print(f"target.shape={target.shape}")
# Out:
# x_data.shape=(70000, 784)
# target.shape=(70000,)

# %%
import pandas as pd

columns = list([f"cell_{num:0>3d}" for num in range(0, 784)])
df = pd.DataFrame(data, columns=columns)

# %%
from pycaret.clustering import *

exp = setup(
    data=df, session_id=123,
    numeric_features=list([f"cell_{num:0>3d}" for num in range(0, 784)]),
    normalize=True, transformation=True)
# Out:
#                                Description                 Value
# 0                               session_id                   123
# 1                            Original Data          (70000, 784)
# 2                           Missing Values                 False
# 3                         Numeric Features                   784
# 4                     Categorical Features                     0
# 5                         Ordinal Features                 False
# 6                High Cardinality Features                 False
# 7                  High Cardinality Method                  None
# 8                         Transformed Data          (70000, 784)
# 9                                 CPU Jobs                    -1
# 10                                 Use GPU                 False
# 11                          Log Experiment                 False
# 12                         Experiment Name  cluster-default-name
# ...

# %%
hclust = create_model("hclust")
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  16:03:48
# Status     . . . . . . . . . . . . . . . . . .        Fitting 4 Clusters
# Estimator  . . . . . . . . . . . . . . . . . .  Agglomerative Clustering
# Empty DataFrame
# Columns: [Silhouette, Calinski-Harabasz, Davies-Bouldin, Homogeneity, Rand Index, Completeness]
# Index: []

# %%
results = assign_model(hclust)
results.head()

# %%
plot_model(hclust)
