# %% [markdown]
# <a href="https://colab.research.google.com/github/applejxd/colaboratory/blob/master/algorithm/linalg_inv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 線形方程式の求解

# %%
# %reset -f

# %% [markdown]
# ## 直接法

# %% [markdown]
# ### LU分解

# %% [markdown]
# LU分解$PA=LU$を求める。
# $P$は置換行列$PP^T=I$、$L$は対角成分1の下三角行列、$U$は上三角行列。
#
# LU分解を求める過程には部分ピボット選択付きガウスの消去法から求める外積形式ガウス法や、$PA=LU$から直接成分を比較して求める内積形式ガウス法が存在。ここでは[外積形式ガウス法](https://cedddnav.org/raspi4a/)を使用。
# この方法は部分ピボット選択付きガウスの消去法を$L^{-1}PA=U$と比較して$P,L,U$を求める。$P$は最終的な部分ピボット選択全体。$L$は行基本変形の積の逆行列であり、各行基本変形の逆行列が非対角成分の符号を反転させたものであることを利用。
#
# $PA\vec{x}=LU\vec{x}=\vec{b}⇔LU\vec{x}=P^T\vec{b}$であるので
# 、$L\vec{y}=P^T\vec{b}, U\vec{x}=\vec{y}$として代入操作で解けば、
# これは前進・後退代入に対応。
#
# ランダムに生成した正方行列で検証。numpy の LU 分解の機能を使う。
# （非正方行列は[疑似逆行列の計算法](https://www.momoyama-usagi.com/entry/math-linear-algebra-ap08)を適用したものとする。）

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 表示の精度を設定
np.set_printoptions(precision=3, suppress=False)
plt.rcParams['figure.figsize'] = (5, 2)

N = 4
A = np.random.rand(N, N)

print("A=")
sns.heatmap(A, annot=True, cmap='coolwarm')
plt.show()
# Out:
# A=

# %% [markdown]
# 部分ピボット選択付きガウスの消去法で LU 分解を実装

# %%
def LU_decomposition(A):
  N = A.shape[0]
  # 置換・行消去は操作なしの単位行列からスタート
  # 前進消去後の行列になる U は A からスタート
  P, L, U = np.eye(N), np.eye(N), A.copy()

  for k in range(N-1):
    # 絶対値の最大要素をピボットとして選択
    # (アンダーフロー・ゼロ除算対策)
    p = np.argmax(abs(U[k:,k])) + k
    if np.isclose(U[p,k], 0):
      raise ValueError("Singular matrix")

    # 行入れ替え
    if p != k:
      P[[k,p],:] = P[[p,k],:]
      U[[k,p],:] = U[[p,k],:]
      if k > 0:
        L[[k,p],:k] = L[[p,k],:k]

    # 前進消去
    for i in range(k+1,N):
      # 基本変形の逆行列 → 符号が逆
      L[i,k] = U[i,k]/U[k,k]
      U[i,:] -= L[i,k]*U[k,:]
  return P, L, U

P, L, U = LU_decomposition(A)

print("P=")
sns.heatmap(P, annot=True, cmap='coolwarm')
plt.show()

print("L=")
sns.heatmap(L, annot=True, cmap='coolwarm')
plt.show()

print("U=")
sns.heatmap(U, annot=True, cmap='coolwarm')
plt.show()
# Out:
# P=
# L=
# U=

# %% [markdown]
# 分解が正しいか検算

# %%
residuals = P @ A - L @ U

print("PA-LU=")
sns.heatmap(residuals, annot=True, cmap='coolwarm')
plt.show()
# Out:
# PA-LU=

# %% [markdown]
# scipy で検算。置換行列$P$は一致しない場合がある。

# %%
import scipy.linalg as linalg
P2, L2, U2 = linalg.lu(A)

print("δP=")
sns.heatmap(P-P2, annot=True, cmap='coolwarm')
plt.show()

print("δL=")
sns.heatmap(L-L2, annot=True, cmap='coolwarm')
plt.show()

print("δU=")
sns.heatmap(U-U2, annot=True, cmap='coolwarm')
plt.show()
# Out:
# δP=
# δL=
# δU=

# %% [markdown]
# ここから$A\vec{x}=\vec{b}$を解くために$\vec{b}$を生成

# %%
b = np.random.rand(N)
print(f"{b=}")
# Out:
# b=array([0.477, 0.911, 0.538, 0.652])

# %% [markdown]
# $L\vec{y}=P^T\vec{b}$ を解く。
# 前進代入は$y_i=b'_i-\sum_{j=0}^{i-1}l_{ij}y_j$。

# %%
def forward_substitute(P, L, b):
  N = len(b)
  y = np.zeros(N)
  for i in range(N):
    y[i] = (P.T @ b)[i] - L[i, :i] @ y[:i]
  return y

y = forward_substitute(P, L, b)
print(f"{y=}")
# Out:
# y=array([ 0.477,  0.245,  1.035, -0.216])

# %% [markdown]
# $U\vec{x}=\vec{y}$ を解く。
# 後退代入は$x_i=(y_i-\sum_{j=i+1}^nu_{ij}x_j)/u_{ii}$。

# %%
def backward_substitute(U, y):
  N = len(y)
  x = np.zeros(N)
  for i in range(N-1, -1, -1):
    x[i] = (y[i] - U[i, i+1:] @ x[i+1:]) / U[i, i]
  return x

x = backward_substitute(U, y)
print(f"{x=}")
# Out:
# x=array([ 0.036,  0.506,  2.093, -1.355])

# %% [markdown]
# 解の検算を実施

# %%
print(f"{A@x-b=}")
# Out:
# A@x-b=array([ 0.00e+00, -1.11e-16,  1.11e-16, -2.22e-16])

# %% [markdown]
# 逆行列もLU分解から求まる。$AA^{-1}=I$なので$A\vec{x}_i=\vec{e}_i$を解けばいい。これは他の手法でも同じ。

# %%
A_inv = np.zeros((N, N))
for i in range(N):
  e_i = np.zeros(N)
  e_i[i] = 1
  y_i = forward_substitute(P, L, e_i)
  x_i = backward_substitute(U, y_i)
  A_inv[:, i] = x_i

print("A_inv=")
sns.heatmap(A_inv, annot=True, cmap='coolwarm')
plt.show()

# 検算
print("AA_inv=")
sns.heatmap(A @ A_inv, annot=True, cmap='coolwarm')
plt.show()
# Out:
# A_inv=
# AA_inv=

# %% [markdown]
# ### コレスキー分解法

# %% [markdown]
# 解くべき連立一次方程式$A\vec{x}=\vec{b}$の係数行列$A$が非負定値対称行列ならコレスキー分解$A=LL^T$が可能なので、これを利用。
# 公式は成分比較で求める。
#
# 対称性は$A$と比較して$L$の成分が半分であることから必要。
# 非不定値は平方根の計算のために必要。
#
# 不定値なら$(A^TA)\vec{x}=A^T\vec{b}$を解く。$A^TA$は必ず対称で非負定値(特異値分解の部分を参照)。

# %% [markdown]
# コレスキー分解は対称正定値行列$A$に対して舌三角行列$L$で$A=LL^T$と分解して、前進・後退代入で$A\vec{x}=\vec{b}$を解く。
# あるいは$(AA^T)\vec{x}=(LL^T)\vec{x}=A^T\vec{b}$とする。

# %%
def cholesky_decomposition(A):
  L = np.zeros_like(A)
  N = A.shape[0]
  for i in range(N):
    for j in range(i+1):
      if i == j:
        L[i, j] = np.sqrt(A[i, i] - np.sum(L[i, :j]**2))
      else:
        L[i, j] = (A[i, j] - np.sum(L[i, :j] * L[j, :j])) / L[j, j]
  return L

L = cholesky_decomposition(A.T @ A)

print("L=")
sns.heatmap(L, annot=True, cmap='coolwarm')
plt.show()

print("LL^T-A^TA=")
sns.heatmap(L @ L.T - A.T @ A, annot=True, cmap='coolwarm')
plt.show()
# Out:
# L=
# LL^T-A^TA=

# %% [markdown]
# 線形方程式$A\vec{x}=\vec{b}$の解法はLU分解と同様

# %%
def forward_substitute(L, b):
  N = len(b)
  y = np.zeros(N)
  for i in range(N):
    y[i] = (b[i] - L[i, :i] @ y[:i]) / L[i, i]
  return y


def backward_substitute(LT, y):
  N = len(y)
  x = np.zeros(N)
  for i in range(N-1, -1, -1):
    x[i] = (y[i] - LT[i, i+1:] @ x[i+1:]) / LT[i, i]
  return x


y = forward_substitute(L, A.T @ b)
x = backward_substitute(L.T, y)
print(f"{A@x-b=}")
# Out:
# A@x-b=array([ 2.220e-16, -2.554e-15, -3.997e-15,  4.996e-15])

# %% [markdown]
# ### 修正コレスキー分解

# %% [markdown]
# 平方根の計算を避ける修正コレスキー分解ではスケール行列$D'$を抜き出して$A=LL^T≡(L'D')(L'D')^T=L'D'D'^TL'^T\equiv L'DL'^T$とする。
# $L'$の対角成分はすべて1である。
#
# 成分比較から分解の公式を求める。

# %%
def modified_cholesky_decomposition(A):
  L, D = np.zeros_like(A), np.zeros_like(A)

  N = A.shape[0]
  for i in range(N):
    for j in range(i+1):
      if i == j:
        L[i, i] = 1
        D[i, i] = A[i, i] - np.sum(L[i, :i]**2 * D[:i, :i])
      else:
        L[i, j] = (A[i, j] - np.sum(L[i, :j] * L[j, :j] * D[:j, :j])) / D[j, j]
  return L, D

L, D = modified_cholesky_decomposition(A.T @ A)

print("L=")
sns.heatmap(L, annot=True, cmap='coolwarm')
plt.show()

print("D=")
sns.heatmap(D, annot=True, cmap='coolwarm')
plt.show()

print("L D L^T - A^T A=")
sns.heatmap(L @ D @ L.T - A.T @ A, annot=True, cmap='coolwarm')
plt.show()
# Out:
# L=
# D=
# L D L^T - A^T A=

# %% [markdown]
# 線形方程式$A\vec{x}=\vec{b}$の解法はコレスキー分解と同様

# %%
def forward_substitute(L, b):
  N = len(b)
  y = np.zeros(N)
  for i in range(N):
    y[i] = (b[i] - L[i, :i] @ y[:i]) / L[i, i]
  return y


def backward_substitute(LT, y):
  N = len(y)
  x = np.zeros(N)
  for i in range(N-1, -1, -1):
    x[i] = (y[i] - LT[i, i+1:] @ x[i+1:]) / LT[i, i]
  return x


y = forward_substitute(L @ D, A.T @ b)
x = backward_substitute(L.T, y)
print(f"{A@x-b=}")
# Out:
# A@x-b=array([ 4.441e-16, -2.220e-15, -4.219e-15,  4.885e-15])

# %% [markdown]
# ## 間接法

# %% [markdown]
# 間接法は反復更新で解に収束させることで解く。
# [大きく定常法と非定常法に分けられる](http://nkl.cc.u-tokyo.ac.jp/13n/SolverIterative.pdf)。

# %% [markdown]
# ### 定常法

# %% [markdown]
# 定常法の収束に対する十分条件は狭義行・列対角優位性なので、ランダム生成した行列$A$では収束しない可能性があることに気を付ける。
#
# このためアルゴリズムチェックでは手動で狭義対角優位な行列を設定する。

# %%
N = 5
A = np.zeros((N, N))
np.fill_diagonal(A, 5)
for i in range(N - 1):
    A[i, i + 1] = 2
    A[i + 1, i] = 2

print("A=")
sns.heatmap(A, annot=True, cmap='coolwarm')
plt.show()
# Out:
# A=

# %%
b = np.random.rand(N)
print(f"{b=}")
# Out:
# b=array([0.743, 0.326, 0.821, 0.509, 0.275])

# %% [markdown]
# 対象の行列$A$を下三角$L$・対角$D$・上三角$U$に分解。つまり$A=D+L+U$。

# %%
L = np.tril(A, -1)
D = np.diag(np.diag(A))
U = np.triu(A, 1)

print("L=")
sns.heatmap(L, annot=True, cmap='coolwarm')
plt.show()

print("D=")
sns.heatmap(D, annot=True, cmap='coolwarm')
plt.show()

print("U=")
sns.heatmap(U, annot=True, cmap='coolwarm')
plt.show()
# Out:
# L=
# D=
# U=

# %% [markdown]
# #### ヤコビ法

# %% [markdown]
# 反復の漸化式は
# \begin{equation}
# \vec{x}^{(k+1)}=D^{-1}(\vec{b}-(L+U)\vec{x}^{(k)})
# \end{equation}

# %%
def jacobi_step(L, D, U, x, b):
  Dinv = np.diag(1/np.diag(D))
  return Dinv @ (b - (L + U) @ x)

# %% [markdown]
# この反復で$A\vec{x}=\vec{b}$を満たす$\vec{x}$を求める。

# %%
max_step = 100
eps = 1e-6

x = np.ones(A.shape[0])
for idx, step in enumerate(range(max_step)):
  x_new = jacobi_step(L, D, U, x, b)
  if np.linalg.norm(x_new - x) < eps:
    break
  x = x_new

print(f"{idx=}")
print(f"{x=}")
print(f"{A@x-b=}")
# Out:
# idx=41
# x=array([ 1.839e-01, -8.807e-02,  1.993e-01,  4.818e-05,  5.503e-02])
# A@x-b=array([-1.447e-06, -2.474e-06, -2.894e-06, -2.474e-06, -1.447e-06])

# %% [markdown]
# #### ガウス・ザイデル法

# %% [markdown]
# 反復の漸化式は
# \begin{equation}
# \vec{x}^{(k+1)}=D^{-1}(\vec{b}-L\vec{x}^{(k+1)}-U\vec{x}^{(k)}).
# \end{equation}
# $L$は下三角なので$x_i^{(k+1)}$の計算で$x_{0,...,i-1}^{(k+1)}$を使用することになる。

# %%
def gauss_seidel_step(L, D, U, x, b):
  Dinv = np.diag(1/np.diag(D))
  x_new = np.zeros_like(x)
  for i in range(len(x)):
    x_new[i] = Dinv[i, i] * (b[i] - L[i, :i] @ x_new[:i] - U[i, i:] @ x[i:])
  return x_new

# %% [markdown]
# この反復で$A\vec{x}=\vec{b}$を満たす$\vec{x}$を求める。

# %%
max_step = 100
eps = 1e-6

x = np.ones(A.shape[0])
for idx, step in enumerate(range(max_step)):
  x_new = gauss_seidel_step(L, D, U, x, b)
  if np.linalg.norm(x_new - x) < eps:
    break
  x = x_new

print(f"{idx=}")
print(f"{x=}")
print(f"{A@x-b=}")
# Out:
# idx=17
# x=array([ 1.839e-01, -8.807e-02,  1.993e-01,  4.795e-05,  5.503e-02])
# A@x-b=array([ 2.297e-06, -1.838e-06,  1.103e-06, -4.410e-07,  0.000e+00])

# %% [markdown]
# #### SOR 法

# %% [markdown]
# 反復の漸化式は
# \begin{equation}
# \vec{x}^{(k+1)}=(1-\omega)\vec{x}^{(k)}+\omega D^{-1}(\vec{b}-L\vec{x}^{(k+1)}-U\vec{x}^{(k)}).
# \end{equation}
# $L$は下三角なので$x_i^{(k+1)}$の計算で$x_{0,...,i-1}^{(k+1)}$を使用することになる。
#
# $\omega=1$でガウス・ザイデル法と一致する。

# %%
def sor_step(L, D, U, x, b, omega):
  Dinv = np.diag(1/np.diag(D))
  x_new = np.zeros_like(x)
  for i in range(len(x)):
    xi = Dinv[i, i] * (b[i] - L[i, :i] @ x_new[:i] - U[i, i:] @ x[i:])
    x_new[i] = (1 - omega) * x[i] + omega * xi
  return x_new

# %% [markdown]
# この反復で$A\vec{x}=\vec{b}$を満たす$\vec{x}$を求める。
# ただし収束の必要条件などから$1<\omega<2$。

# %%
max_step = 100
eps = 1e-6
omega = 1.22

x = np.ones(A.shape[0])
for idx, step in enumerate(range(max_step)):
  x_new = sor_step(L, D, U, x, b, omega)
  if np.linalg.norm(x_new - x) < eps:
    break
  x = x_new

print(f"{idx=}")
print(f"{x=}")
print(f"{A@x-b=}")
# Out:
# idx=11
# x=array([ 1.839e-01, -8.807e-02,  1.993e-01,  4.847e-05,  5.503e-02])
# A@x-b=array([-2.069e-06, -5.100e-07, -2.515e-07, -3.118e-07, -3.603e-07])

# %% [markdown]
# ### 非定常法

# %% [markdown]
# #### 共役勾配法

# %% [markdown]
# まずはランダム行列を生成する

# %%
N = 4
A = np.random.rand(N, N)
b = np.random.rand(N)

print("A=")
sns.heatmap(A, annot=True, cmap='coolwarm')
plt.show()

print(f"{b=}")
# Out:
# A=
# b=array([0.404, 0.94 , 0.098, 0.849])

# %% [markdown]
# 共役勾配法は対称正定値行列$A$に対して2次形式の最適化問題
# \begin{equation}
# \min_{\vec{x}}f(\vec{x})
# \equiv
# \min_{\vec{x}}\left(\frac{1}{2}(\vec{x},A\vec{x})-(\vec{x},\vec{b})\right)
# \end{equation}
# に変形して適用。
#
# A が対称正定値でなければ $A^TA$ を $A$ として処理する。

# %% [markdown]
# 暫定解$\vec{x}_k$に対し探索方向$\vec{p}_k$で$f(\vec{x})$が最小になる点は$\vec{r}_k\equiv\vec{b}-A\vec{x}_k$として
# \begin{equation}
# \vec{x}_{k+1}=\vec{x}_k+\frac{(\vec{p}_k,\vec{r}_k)}{(\vec{p}_k,A\vec{p}_k)}\vec{p}_k.
# \end{equation}

# %% [markdown]
# 勾配方向$\vec{p}$は共役の条件$(\vec{p}_{k+1},A\vec{p}_k)=0$から決定する。

# %%
max_step = 100
eps = 1e-6

ATA = A.T @ A

x = np.ones(ATA.shape[0])
p = A.T @ b - ATA @ x
r = A.T @ b - ATA @ x

for idx, step in enumerate(range(max_step)):
  alpha = np.dot(p, r) / np.dot(p, ATA @ p)
  x = x + alpha * p
  r = r - alpha * ATA @ p
  if np.linalg.norm(r) < eps:
    break
  else:
    beta = - np.dot(r, ATA @ p) / np.dot(p, ATA @ p)
    p = r + beta * p

print(f"{idx=}")
print(f"{x=}")
print(f"{ATA@x-A.T@b=}")
# Out:
# idx=3
# x=array([-4.437,  4.234,  0.648,  3.018])
# ATA@x-A.T@b=array([1.065e-10, 2.516e-11, 1.306e-10, 1.255e-10])

# %% [markdown]
# 共役勾配法は$\dim\vec{b}$回の反復で$A\vec{x}=\vec{b}$の解が得られることが保証されている。
